# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("../DataSets/individual/income-type.csv")

# %%
df
# Out:
#      year_of_assessment                       income_type    amount
# 0                  2004                         Dividends   3324172
# 1                  2004                 Employment Income  62022432
# 2                  2004  Income from Trade and Profession   4409580
# 3                  2004                          Interest    211648
# 4                  2004                       Other Types    902053
# ..                  ...                               ...       ...
# 107                2019  Income from Trade and Profession   8384500
# 108                2019                          Interest     60633
# 109                2019                       Other Types    192922
# 110                2019                              Rent   4764152
# 111                2019                         Royalties      7883
#
# [112 rows x 3 columns]

# %%
df.income_type.unique()
# Out:
# array(['Dividends', 'Employment Income',
#        'Income from Trade and Profession', 'Interest', 'Other Types',
#        'Rents/ Net Annual Value', 'Royalties', 'Rent'], dtype=object)

# %%
pd.crosstab(index=df.year_of_assessment,columns=df.income_type,values=df.amount,aggfunc='sum',margins=True)
# Out:
# income_type          Dividends  Employment Income  \
# year_of_assessment
# 2004                 3324172.0       6.202243e+07
# 2005                 2974005.0       6.227515e+07
# 2006                 3285138.0       6.593225e+07
# 2007                 3178311.0       7.462863e+07
# 2008                 3016587.0       8.733156e+07
# 2009                   10941.0       9.823322e+07
# 2010                   11517.0       9.845468e+07
# 2011                   11811.0       1.106634e+08
# 2012                   11706.0       1.236228e+08
# 2013                   12243.0       1.331534e+08
# 2014                   24260.0       1.440474e+08
# 2015                   21837.0       1.554565e+08
# 2016                   27104.0       1.653992e+08
# 2017                   21521.0       1.710163e+08
# 2018                   20734.0       1.777865e+08
# 2019                   20178.0       1.868146e+08
# All                 15972065.0       1.916838e+09
#
# ...

# %%
me=df

# %%
me
# Out:
#      year_of_assessment                       income_type    amount
# 0                  2004                         Dividends   3324172
# 1                  2004                 Employment Income  62022432
# 2                  2004  Income from Trade and Profession   4409580
# 3                  2004                          Interest    211648
# 4                  2004                       Other Types    902053
# ..                  ...                               ...       ...
# 107                2019  Income from Trade and Profession   8384500
# 108                2019                          Interest     60633
# 109                2019                       Other Types    192922
# 110                2019                              Rent   4764152
# 111                2019                         Royalties      7883
#
# [112 rows x 3 columns]

# %%
me.groupby('year_of_assessment')['income_type'].sum()
# Out:
# year_of_assessment
# 2004    DividendsEmployment IncomeIncome from Trade an...
# 2005    DividendsEmployment IncomeIncome from Trade an...
# 2006    DividendsEmployment IncomeIncome from Trade an...
# 2007    DividendsEmployment IncomeIncome from Trade an...
# 2008    DividendsEmployment IncomeIncome from Trade an...
# 2009    DividendsEmployment IncomeIncome from Trade an...
# 2010    DividendsEmployment IncomeIncome from Trade an...
# 2011    DividendsEmployment IncomeIncome from Trade an...
# 2012    DividendsEmployment IncomeIncome from Trade an...
# 2013    DividendsEmployment IncomeIncome from Trade an...
# 2014    DividendsEmployment IncomeIncome from Trade an...
# 2015    DividendsEmployment IncomeIncome from Trade an...
# 2016    DividendsEmployment IncomeIncome from Trade an...
# 2017    DividendsEmployment IncomeIncome from Trade an...
# 2018    DividendsEmployment IncomeIncome from Trade an...
# 2019    DividendsEmployment IncomeIncome from Trade an...
# ...

# %%
pd.pivot_table(data=df,index='year_of_assessment',columns='income_type',values='amount',margins=True)
# Out:
# income_type            Dividends  Employment Income  \
# year_of_assessment
# 2004                3.324172e+06       6.202243e+07
# 2005                2.974005e+06       6.227515e+07
# 2006                3.285138e+06       6.593225e+07
# 2007                3.178311e+06       7.462863e+07
# 2008                3.016587e+06       8.733156e+07
# 2009                1.094100e+04       9.823322e+07
# 2010                1.151700e+04       9.845468e+07
# 2011                1.181100e+04       1.106634e+08
# 2012                1.170600e+04       1.236228e+08
# 2013                1.224300e+04       1.331534e+08
# 2014                2.426000e+04       1.440474e+08
# 2015                2.183700e+04       1.554565e+08
# 2016                2.710400e+04       1.653992e+08
# 2017                2.152100e+04       1.710163e+08
# 2018                2.073400e+04       1.777865e+08
# 2019                2.017800e+04       1.868146e+08
# All                 9.982541e+05       1.198024e+08
#
# ...

# %%
sb.lineplot(x=me.income_type,y=me.year_of_assessment)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Yash Jadhao\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Yash Jadhao\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.pairplot(df)
plt.show()
# Out:
# C:\Users\Yash Jadhao\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Yash Jadhao\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print(df.year_of_assessment.unique())
a=int(input("Enter year"))
b=df[df.year_of_assessment==a]
# print(b.income_type.unique())
# c=input("Enter amount Name")
# d=b[b.income_type==c]
sb.barplot(x=b.income_type,y=b.amount)
plt.xticks(rotation=90)
plt.show()
# Out:
# [2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019]
# Enter year 2007

# %%
df.nlargest(10,'amount')
# Out:
#      year_of_assessment        income_type     amount
# 106                2019  Employment Income  186814640
# 99                 2018  Employment Income  177786497
# 92                 2017  Employment Income  171016265
# 85                 2016  Employment Income  165399170
# 78                 2015  Employment Income  155456464
# 71                 2014  Employment Income  144047365
# 64                 2013  Employment Income  133153378
# 57                 2012  Employment Income  123622839
# 50                 2011  Employment Income  110663416
# 43                 2010  Employment Income   98454678

# %%
df.nsmallest(10,'amount')
# Out:
#     year_of_assessment income_type  amount
# 13                2005   Royalties    3101
# 27                2007   Royalties    3419
# 20                2006   Royalties    3642
# 6                 2004   Royalties    3645
# 41                2009   Royalties    5024
# 34                2008   Royalties    5221
# 48                2010   Royalties    5281
# 83                2015   Royalties    5353
# 90                2016   Royalties    5478
# 62                2012   Royalties    5524

# %% [raw]
# 10 HIGHEST AND LOWEST AMOUNT

# %%
print(df.income_type.unique())
a=input("income_type")
b=df[df.income_type== a]
b.groupby('year_of_assessment')['amount'].sum()
# Out:
# ['Dividends' 'Employment Income' 'Income from Trade and Profession'
#  'Interest' 'Other Types' 'Rents/ Net Annual Value' 'Royalties' 'Rent']
# income_type Rent
# year_of_assessment
# 2010    2542073
# 2011    2689232
# 2012    3236243
# 2013    3795735
# 2014    4299050
# 2015    4690606
# 2016    4726335
# 2017    4758361
# 2018    4774996
# 2019    4764152
# Name: amount, dtype: int64

# %%
sb.boxplot(df.amount)
plt.show()

# %%
i= 'amount'
q1 =np.percentile (df[i],25)
q3 = np.percentile (df[i],75)
iqr=q3-q1
c1=q1-(1.5*iqr)
c2=q3+ (1.5*iqr)
dt=df[(df[i]>=c2)|(df[i]<=c1)]

# %%
dt
# Out:
#      year_of_assessment        income_type     amount
# 1                  2004  Employment Income   62022432
# 8                  2005  Employment Income   62275153
# 15                 2006  Employment Income   65932248
# 22                 2007  Employment Income   74628627
# 29                 2008  Employment Income   87331563
# 36                 2009  Employment Income   98233219
# 43                 2010  Employment Income   98454678
# 50                 2011  Employment Income  110663416
# 57                 2012  Employment Income  123622839
# 64                 2013  Employment Income  133153378
# 71                 2014  Employment Income  144047365
# 78                 2015  Employment Income  155456464
# 85                 2016  Employment Income  165399170
# 92                 2017  Employment Income  171016265
# 99                 2018  Employment Income  177786497
# 106                2019  Employment Income  186814640

# %%
dt=dt.index

# %%
dt
# Out:
# Index([1, 8, 15, 22, 29, 36, 43, 50, 57, 64, 71, 78, 85, 92, 99, 106], dtype='int64')

# %%
dt=df.drop(labels=dt)

# %%
sb.boxplot(dt.amount)
plt.show()
